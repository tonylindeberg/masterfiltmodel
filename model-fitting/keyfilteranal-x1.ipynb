# %%
import math
import numpy as np
from matplotlib import pyplot as plt
from importlib import reload

# %%
import filteranal

# %%
reload(filteranal)
# Out:
# <module 'filteranal' from '/Users/tony/Work/python/gaussderfit/filteranal.py'>

# %%
filter7 = filteranal.keyfilter(7)
plt.imshow(filter7, interpolation='nearest', extent=[-3.5, 3.5, -3.5, 3.5])
plt.tight_layout()

# %%
filter7 = filteranal.keyfilter('norm7')
amin = np.min(filter7)
amax = np.max(filter7)
arange = max(abs(amin), abs(amax))
plt.imshow(filter7, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')

# %%
filter7 = filteranal.keyfilter('sepfromcontvarnorm7')
amin = np.min(filter7)
amax = np.max(filter7)
arange = max(abs(amin), abs(amax))
plt.imshow(filter7, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')

# %%
filter7 = filteranal.keyfilter('jointfromcontvarnorm7')
amin = np.min(filter7)
amax = np.max(filter7)
arange = max(abs(amin), abs(amax))
plt.imshow(filter7, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')

# %%
filter7 = filteranal.keyfilter('sepfromdiscvarnorm7')
amin = np.min(filter7)
amax = np.max(filter7)
arange = max(abs(amin), abs(amax))
plt.imshow(filter7, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')

# %%
filter7 = filteranal.keyfilter('jointfromdiscvarnorm7')
amin = np.min(filter7)
amax = np.max(filter7)
arange = max(abs(amin), abs(amax))
plt.imshow(filter7, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')

# %%
filter7 = filteranal.keyfilter('samescalefroml1diff7')
amin = np.min(filter7)
amax = np.max(filter7)
arange = max(abs(amin), abs(amax))
plt.imshow(filter7, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')

# %%
filter7 = filteranal.keyfilter('jointscalefroml1diff7')
amin = np.min(filter7)
amax = np.max(filter7)
arange = max(abs(amin), abs(amax))
plt.imshow(filter7, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')

# %%
filter7 = filteranal.keyfilter('samescalefroml2diff7')
amin = np.min(filter7)
amax = np.max(filter7)
arange = max(abs(amin), abs(amax))
plt.imshow(filter7, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')

# %%
filter7 = filteranal.keyfilter('jointscalefroml2diff7')
amin = np.min(filter7)
amax = np.max(filter7)
arange = max(abs(amin), abs(amax))
plt.imshow(filter7, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')

# %%
sigmaxmin = 0.4
sigmaxmax = 0.9
sigmaymin = 0.4
sigmaymax = 0.9
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel2diff(1, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (37, 128)

# %%
sigmaxvec[37]
# Out:
# 0.49296482412060305

# %%
sigmayvec[128]
# Out:
# 0.721608040201005

# %%
sigmaxmin = 0.45
sigmaxmax = 0.55
sigmaymin = 0.69
sigmaymax = 0.74
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel2diff(1, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (82, 129)

# %%
sigmaxvec[82]
# Out:
# 0.4912060301507538

# %%
sigmayvec[129]
# Out:
# 0.7224120603015075

# %%
sigmaxmin = 0.4
sigmaxmax = 0.9
sigmaymin = 0.4
sigmaymax = 0.9
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel2diff(2, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (72, 47)

# %%
sigmaxvec[72]
# Out:
# 0.5809045226130654

# %%
sigmayvec[47]
# Out:
# 0.5180904522613066

# %%
sigmaxmin = 0.56
sigmaxmax = 0.61
sigmaymin = 0.49
sigmaymax = 0.54
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel2diff(2, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (85, 114)

# %%
sigmaxvec[85]
# Out:
# 0.581356783919598

# %%
sigmayvec[114]
# Out:
# 0.518643216080402

# %%
sigmaxmin = 0.4
sigmaxmax = 0.9
sigmaymin = 0.4
sigmaymax = 0.9
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel2diff(3, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (33, 41)

# %%
sigmaxvec[33]
# Out:
# 0.4829145728643216

# %%
sigmayvec[41]
# Out:
# 0.5030150753768845

# %%
sigmaxmin = 0.46
sigmaxmax = 0.51
sigmaymin = 0.48
sigmaymax = 0.53
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel2diff(3, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (92, 91)

# %%
sigmaxvec[92]
# Out:
# 0.48311557788944726

# %%
sigmayvec[91]
# Out:
# 0.5028643216080402

# %%
sigmaxmin = 0.1
sigmaxmax = 1.0
sigmaymin = 0.0001
sigmaymax = 1.0
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel2diff(4, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (89, 0)

# %%
sigmaxvec[89]
# Out:
# 0.5025125628140703

# %%
sigmayvec[0]
# Out:
# 0.0001

# %%
sigmaxmin = 0.48
sigmaxmax = 0.51
sigmaymin = 0.0001
sigmaymax = 0.02
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel2diff(4, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (139, 1)

# %%
sigmaxvec[139]
# Out:
# 0.5009547738693467

# %%
sigmayvec[1]
# Out:
# 0.0002

# %%
sigmaxmin = 0.7
sigmaxmax = 1.4
sigmaymin = 0.7
sigmaymax = 1.4
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel2diff(5, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (170, 87)

# %%
sigmaxvec[170]
# Out:
# 1.2979899497487435

# %%
sigmayvec[87]
# Out:
# 1.0060301507537688

# %%
sigmaxmin = 1.25
sigmaxmax = 1.35
sigmaymin = 0.95
sigmaymax = 1.05
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel2diff(5, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (99, 108)

# %%
sigmaxvec[99]
# Out:
# 1.299748743718593

# %%
sigmayvec[108]
# Out:
# 1.0042713567839197

# %%
sigmaxmin = 0.7
sigmaxmax = 1.4
sigmaymin = 0.7
sigmaymax = 1.4
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel2diff(6, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (81, 106)

# %%
sigmaxvec[81]
# Out:
# 0.9849246231155778

# %%
sigmaxvec[106]
# Out:
# 1.0728643216080402

# %%
sigmaxmin = 0.93
sigmaxmax = 1.03
sigmaymin = 1.02
sigmaymax = 1.12
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel2diff(6, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (108, 107)

# %%
sigmaxvec[108]
# Out:
# 0.9842713567839196

# %%
sigmayvec[107]
# Out:
# 1.0737688442211055

# %%
sigmaxmin = 0.5
sigmaxmax = 0.7
sigmaymin = 0.5
sigmaymax = 0.7
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel2diff(8, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (115, 108)

# %%
sigmaxvec[115]
# Out:
# 0.6155778894472361

# %%
sigmayvec[108]
# Out:
# 0.6085427135678392

# %%
sigmaxmin = 0.59
sigmaxmax = 0.64
sigmaymin = 0.58
sigmaymax = 0.63
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel2diff(8, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (102, 112)

# %%
sigmaxvec[102]
# Out:
# 0.6156281407035176

# %%
sigmayvec[112]
# Out:
# 0.608140703517588

# %%
sigmaxmin = 0.4
sigmaxmax = 0.7
sigmaymin = 0.4
sigmaymax = 0.7
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel1diff(8, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (157, 124)

# %%
sigmaxvec[157]
# Out:
# 0.6366834170854271

# %%
sigmayvec[124]
# Out:
# 0.5869346733668341

# %%
sigmaxmin = 0.61
sigmaxmax = 0.66
sigmaymin = 0.56
sigmaymax = 0.61
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel1diff(8, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (106, 106)

# %%
sigmaxvec[106]
# Out:
# 0.6366331658291458

# %%
sigmayvec[106]
# Out:
# 0.5866331658291457

# %%
sigmaxmin = 0.02
sigmaxmax = 0.6
sigmaymin = 0.4
sigmaymax = 0.9
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel1diff(1, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (117, 44)

# %%
sigmaxvec[117]
# Out:
# 0.36100502512562815

# %%
sigmayvec[44]
# Out:
# 0.5105527638190955

# %%
sigmaxmin = 0.33
sigmaxmax = 0.39
sigmaymin = 0.48
sigmaymax = 0.54
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel1diff(1, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (100, 101)

# %%
sigmaxvec[100]
# Out:
# 0.36015075376884426

# %%
sigmayvec[101]
# Out:
# 0.5104522613065327

# %%
sigmaxmin = 0.2
sigmaxmax = 0.8
sigmaymin = 0.01
sigmaymax = 0.6
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel1diff(2, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (117, 149)

# %%
sigmaxvec[117]
# Out:
# 0.5527638190954774

# %%
sigmayvec[149]
# Out:
# 0.45175879396984925

# %%
sigmaxmin = 0.52
sigmaxmax = 0.58
sigmaymin = 0.42
sigmaymax = 0.48
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel1diff(2, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (115, 110)

# %%
sigmaxvec[115]
# Out:
# 0.5546733668341708

# %%
sigmayvec[110]
# Out:
# 0.4531658291457286

# %%
sigmaxmin = 0.4
sigmaxmax = 1.2
sigmaymin = 0.01
sigmaymax = 0.8
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel1diff(3, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (74, 162)

# %%
sigmaxvec[74]
# Out:
# 0.6974874371859296

# %%
sigmayvec[162]
# Out:
# 0.6531155778894473

# %%
sigmaxmin = 0.67
sigmaxmax = 0.72
sigmaymin = 0.63
sigmaymax = 0.68
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel1diff(3, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (122, 100)

# %%
sigmaxvec[122]
# Out:
# 0.7006532663316583

# %%
sigmayvec[100]
# Out:
# 0.6551256281407035

# %%
sigmaxmin = 0.2
sigmaxmax = 0.8
sigmaymin = 0.01
sigmaymax = 0.7
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel1diff(4, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (120, 108)

# %%
sigmaxvec[120]
# Out:
# 0.5618090452261306

# %%
sigmayvec[108]
# Out:
# 0.3844723618090452

# %%
sigmaxmin = 0.53
sigmaxmax = 0.60
sigmaymin = 0.36
sigmaymax = 0.41
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel1diff(4, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (93, 97)

# %%
sigmaxvec[93]
# Out:
# 0.562713567839196

# %%
sigmayvec[97]
# Out:
# 0.3843718592964824

# %%
sigmaxmin = 0.1
sigmaxmax = 3.0
sigmaymin = 0.1
sigmaymax = 3.0
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel1diff(5, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (83, 53)

# %%
sigmaxvec[83]
# Out:
# 1.3095477386934675

# %%
sigmayvec[53]
# Out:
# 0.8723618090452261

# %%
sigmaxmin = 1.25
sigmaxmax = 1.35
sigmaymin = 0.82
sigmaymax = 0.92
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel1diff(5, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (118, 110)

# %%
sigmaxvec[118]
# Out:
# 1.3092964824120603

# %%
sigmayvec[110]
# Out:
# 0.8752763819095477

# %%
sigmaxmin = 0.1
sigmaxmax = 3.0
sigmaymin = 0.1
sigmaymax = 3.0
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel1diff(6, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (59, 73)

# %%
sigmaxvec[59]
# Out:
# 0.9597989949748743

# %%
sigmayvec[73]
# Out:
# 1.163819095477387

# %%
sigmaxmin = 0.93
sigmaxmax = 0.99
sigmaymin = 1.13
sigmaymax = 1.20
numsamples = 200
diffmap, sigmaxvec, sigmayvec = filteranal.mapkeyfiltertwoscalel1diff(6, sigmaxmin, sigmaxmax, sigmaymin, sigmaymax, numsamples)
amin = np.min(diffmap)
amax = np.max(diffmap)
arange = max(abs(amin), abs(amax))
plt.imshow(diffmap, cmap='gray', interpolation='nearest', extent=[sigmaxmin, sigmaxmax, sigmaymin, sigmaymax])
plt.set_cmap('bwr')

# %%
np.unravel_index(diffmap.argmin(), diffmap.shape)
# Out:
# (143, 117)

# %%
sigmaxvec[142]
# Out:
# 0.9728140703517588

# %%
sigmayvec[117]
# Out:
# 1.1711557788944722

# %%
filter1 = filteranal.keyfilter('sepscalefroml1diff1')
amin = np.min(filter1)
amax = np.max(filter1)
arange = max(abs(amin), abs(amax))
plt.imshow(filter1, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml1diff1-bluered.eps')

# %%
filter2 = filteranal.keyfilter('sepscalefroml1diff2')
amin = np.min(filter2)
amax = np.max(filter2)
arange = max(abs(amin), abs(amax))
plt.imshow(filter2, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml1diff2-bluered.eps')

# %%
filter3 = filteranal.keyfilter('sepscalefroml1diff3')
amin = np.min(filter3)
amax = np.max(filter3)
arange = max(abs(amin), abs(amax))
plt.imshow(filter3, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml1diff3-bluered.eps')

# %%
filter4 = filteranal.keyfilter('sepscalefroml1diff4')
amin = np.min(filter4)
amax = np.max(filter4)
arange = max(abs(amin), abs(amax))
plt.imshow(filter4, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml1diff4-bluered.eps')

# %%
filter5 = filteranal.keyfilter('sepscalefroml1diff5')
amin = np.min(filter5)
amax = np.max(filter5)
arange = max(abs(amin), abs(amax))
plt.imshow(filter5, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml1diff5-bluered.eps')

# %%
filter6 = filteranal.keyfilter('sepscalefroml1diff6')
amin = np.min(filter6)
amax = np.max(filter6)
arange = max(abs(amin), abs(amax))
plt.imshow(filter6, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml1diff6-bluered.eps')

# %%
filter7 = filteranal.keyfilter('sepscalefroml1diff7')
amin = np.min(filter7)
amax = np.max(filter7)
arange = max(abs(amin), abs(amax))
plt.imshow(filter7, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml1diff7-bluered.eps')

# %%
filter8 = filteranal.keyfilter('sepscalefroml1diff8')
amin = np.min(filter8)
amax = np.max(filter8)
arange = max(abs(amin), abs(amax))
plt.imshow(filter8, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml1diff8-bluered.eps')

# %%
filter1 = filteranal.keyfilter('sepscalefroml2diff1')
amin = np.min(filter1)
amax = np.max(filter1)
arange = max(abs(amin), abs(amax))
plt.imshow(filter1, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml2diff1-bluered.eps')

# %%
filter2 = filteranal.keyfilter('sepscalefroml2diff2')
amin = np.min(filter2)
amax = np.max(filter2)
arange = max(abs(amin), abs(amax))
plt.imshow(filter2, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml2diff2-bluered.eps')

# %%
filter3 = filteranal.keyfilter('sepscalefroml2diff3')
amin = np.min(filter3)
amax = np.max(filter3)
arange = max(abs(amin), abs(amax))
plt.imshow(filter3, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml2diff3-bluered.eps')

# %%
filter4 = filteranal.keyfilter('sepscalefroml2diff4')
amin = np.min(filter4)
amax = np.max(filter4)
arange = max(abs(amin), abs(amax))
plt.imshow(filter4, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml2diff4-bluered.eps')

# %%
filter5 = filteranal.keyfilter('sepscalefroml2diff5')
amin = np.min(filter5)
amax = np.max(filter5)
arange = max(abs(amin), abs(amax))
plt.imshow(filter5, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml2diff5-bluered.eps')

# %%
filter6 = filteranal.keyfilter('sepscalefroml2diff6')
amin = np.min(filter6)
amax = np.max(filter6)
arange = max(abs(amin), abs(amax))
plt.imshow(filter6, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml2diff6-bluered.eps')

# %%
filter7 = filteranal.keyfilter('sepscalefroml2diff7')
amin = np.min(filter7)
amax = np.max(filter7)
arange = max(abs(amin), abs(amax))
plt.imshow(filter7, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml2diff7-bluered.eps')

# %%
filter8 = filteranal.keyfilter('sepscalefroml2diff8')
amin = np.min(filter8)
amax = np.max(filter8)
arange = max(abs(amin), abs(amax))
plt.imshow(filter8, cmap='gray', interpolation='nearest', vmin=-arange, vmax=arange, extent=[-3.5, 3.5, -3.5, 3.5])
plt.set_cmap('bwr')
plt.tight_layout()
plt.savefig('figs/filter-sepscalefroml2diff8-bluered.eps')
